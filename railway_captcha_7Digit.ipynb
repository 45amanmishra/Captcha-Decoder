# %%
import numpy as np
import glob
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import os
# %tensorflow_version 1.x
from PIL import Image
from keras import layers
from keras.models import Model
from keras.models import load_model
from keras.utils.vis_utils import plot_model
from keras import callbacks
from datetime import datetime
import os
import cv2
import string
import numpy as np


from keras.models import Model
from keras.layers import Input, Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
import warnings
warnings.filterwarnings('ignore')
from keras import models
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Dropout
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint


from keras import layers        
from keras.models import Model
from keras.models import load_model
from keras import callbacks
import cv2
import string
import numpy as np
from datetime import datetime
from packaging import version
import tensorflow as tf
from tensorflow import keras
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.

# %%
! wget "https://ndownloader.figshare.com/files/22150851" -O railway_captcha7.tar.gz
# Out:
# --2021-11-24 15:33:35--  https://ndownloader.figshare.com/files/22150851
# Resolving ndownloader.figshare.com (ndownloader.figshare.com)... 54.217.124.219, 52.16.102.173, 2a05:d018:1f4:d000:b283:27aa:b939:8ed4, ...
# Connecting to ndownloader.figshare.com (ndownloader.figshare.com)|54.217.124.219|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://s3-eu-west-1.amazonaws.com/pfigshare-u-files/22150851/railway_captcha7.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIYCQYOYV5JSSROOA/20211124/eu-west-1/s3/aws4_request&X-Amz-Date=20211124T153336Z&X-Amz-Expires=10&X-Amz-SignedHeaders=host&X-Amz-Signature=8d1de2dee987e4d0902e3cc8e5057f72a5b1c11196a680b62d9d812c092febfd [following]
# --2021-11-24 15:33:36--  https://s3-eu-west-1.amazonaws.com/pfigshare-u-files/22150851/railway_captcha7.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIYCQYOYV5JSSROOA/20211124/eu-west-1/s3/aws4_request&X-Amz-Date=20211124T153336Z&X-Amz-Expires=10&X-Amz-SignedHeaders=host&X-Amz-Signature=8d1de2dee987e4d0902e3cc8e5057f72a5b1c11196a680b62d9d812c092febfd
# Resolving s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)... 52.218.62.155
# Connecting to s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)|52.218.62.155|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 303180031 (289M) [application/gzip]
# Saving to: ‘railway_captcha7.tar.gz’
#
# railway_captcha7.ta 100%[===================>] 289.13M  11.4MB/s    in 28s
#
# 2021-11-24 15:34:05 (10.5 MB/s) - ‘railway_captcha7.tar.gz’ saved [303180031/303180031]

# %%
# !tar -xvf railway_captcha7.tar.gz > /dev/null
! echo "Untaring... done..."
# Out:
# Untaring... done...

# %%
png_files = glob.glob('railway_captcha7/*.jpg')
print("Total # of files => ",len(png_files))
png_files[0]
# Out:
# Total # of files =>  100000
# 'railway_captcha7/4886492_46936.jpg'

# %%
symbols = "ABCDEFGHIJKLMNOPQRSTUVWXYZ" + '0123456789' # These are all symbols the captchas will have
num_symbols = len(symbols)
img = np.array(Image.open(png_files[0]))
shape_ = img.shape
print(shape_, num_symbols)
# Out:
# (60, 200, 3) 36

# %%
img_path = png_files[1]
img = cv2.imread(img_path,cv2.IMREAD_UNCHANGED)
plt.imshow(img)
plt.show()

# %%
img_path = png_files[1]
img_gray = cv2.imread(img_path,cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray,cmap='gray')
plt.show()
print(img_gray.shape)
# Out:
# (60, 200)

# %%
# perform OTSU's thresholding
ret,thresh = cv2.threshold(img_gray,127,255,cv2.THRESH_BINARY_INV)
plt.imshow(thresh,cmap='gray')
plt.show()
print(thresh.shape)
# Out:
# (60, 200)

# %%
kernel = np.ones((2,2),np.uint8)
#dialate = cv2.dilate(thresh,kernel,iterations = 1)
erosion = cv2.erode(thresh,kernel,iterations = 1)
plt.imshow(erosion,cmap='gray')
plt.show()

# %%
#kernel = np.ones((2,2),np.uint8)
dialate = cv2.dilate(erosion,kernel,iterations = 2)
#erosion = cv2.erode(thresh,kernel,iterations = 1)
plt.imshow(dialate,cmap='gray')
plt.show()

# %%
total_img = 36
num_pr = 6 # number per row

counter = 1
plt.figure(figsize=(30,15))
plt.axis('off')
for item in png_files[:total_img]:
  image = cv2.imread(item, cv2.IMREAD_GRAYSCALE)
  #img = cv2.resize(img, (200,60), interpolation = cv2.INTER_AREA)
  ret,thresh = cv2.threshold(image,127,255,cv2.THRESH_BINARY_INV)
  # firstly perform erosion
  erosion = cv2.erode(thresh,kernel,iterations = 1)
  # perform dialation
  dialate = cv2.dilate(erosion,kernel,iterations = 2)
  
  #print(pred)
  image_bckup = dialate.copy()
  plt.subplot(num_pr, num_pr, counter)
  #print("item => ",item)
  #print("item => ",str(item.split('_')[1]).split('/')[1])
  plt.title("Name = {}".format(str(item.split('_')[1]).split('/')[1]),fontsize=20).set_color('black')
  plt.axis('off')
  plt.imshow(image_bckup, cmap=plt.get_cmap('gray'))
  counter += 1
  #break
plt.show()

# %%
def create_model():
  in_ = Input(shape=img_shape)
  out = in_
  out = Conv2D(filters=32, kernel_size=(3, 3), padding='same', activation='relu')(out)
  out = Conv2D(filters=32, kernel_size=(3, 3), activation='relu')(out)
  out = BatchNormalization()(out)
  out = MaxPooling2D(pool_size=(2, 2))(out)
  out = Dropout(0.3)(out)
  out = Conv2D(filters=64, kernel_size=(3, 3), padding='same', activation='relu')(out)
  out = Conv2D(filters=64, kernel_size=(3, 3), activation='relu')(out)
  out = BatchNormalization()(out)
  out = MaxPooling2D(pool_size=(2, 2))(out)
  out = Dropout(0.3)(out)
  out = Conv2D(filters=128, kernel_size=(3, 3), padding='same', activation='relu')(out)
  out = Conv2D(filters=128, kernel_size=(3, 3), activation='relu')(out)
  out = BatchNormalization()(out)
  out = MaxPooling2D(pool_size=(2, 2))(out)
  out = Dropout(0.3)(out)
  out = Conv2D(filters=256, kernel_size=(3, 3), activation='relu')(out)
  out = BatchNormalization()(out)
  out = MaxPooling2D(pool_size=(2, 2))(out)
  out = Flatten()(out)
  out = Dropout(0.3)(out)
  out = [Dense(36, name='digit1', activation='softmax')(out),\
        Dense(36, name='digit2', activation='softmax')(out),\
        Dense(36, name='digit3', activation='softmax')(out),\
        Dense(36, name='digit4', activation='softmax')(out),\
        Dense(36, name='digit5', activation='softmax')(out),\
        Dense(36, name='digit6', activation='softmax')(out),
        Dense(36, name='digit7', activation='softmax')(out)
        ]
  model = Model(inputs=in_, outputs=out)
  model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
  return model

# %%
from tqdm import tqdm
kernel = np.ones((2,2),np.uint8)
letters_in_captcha = 7
def preprocess_data():
  n_samples = len(os.listdir('railway_captcha7/'))
  X = np.zeros((n_samples, 200, 60, 1)) #1070*50*200
  print(num_symbols,n_samples)
  y = np.zeros((letters_in_captcha, n_samples, num_symbols)) #5*1070*36
  for i, pic in tqdm(enumerate(os.listdir('railway_captcha7/'))):
    # Read image as grayscale
    img = cv2.imread(os.path.join('railway_captcha7/', pic), cv2.IMREAD_GRAYSCALE)
    ret,thresh = cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)
    # firstly perform erosion
    erosion = cv2.erode(thresh,kernel,iterations = 1)
    # perform dialation
    dialate = cv2.dilate(erosion,kernel,iterations = 2)
    img = dialate.copy()
    pic_target = pic.split('_')[0]
    img = img / 255.0
    #plt.imshow(img,cmap='gray')
    img = np.reshape(img, (200, 60, 1))
    # Define targets and code them using OneHotEncoding
    targs = np.zeros((letters_in_captcha, num_symbols))
    #print("num symbols = ",num_symbols)
    for j, l in enumerate(pic_target):
      ind = symbols.find(l)
      targs[j, ind] = 1
    X[i] = img
    y[:, i] = targs
    
  # Return final data
  return X, y

X, y = preprocess_data()
# Out:
# 36 100000
# 100000it [00:30, 3294.61it/s]

# %%
X_train, y_train = X[:90000], y[:, :90000]
X_test, y_test = X[90000:], y[:, 90000:]

# %%
plt.imshow(X_train[0].reshape((60,200)),cmap='gray')
plt.show()
print(X_train[0].shape)
# Out:
# (200, 60, 1)

# %%
img_shape = (200, 60, 1)
model=create_model();
model.summary();
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 200, 60, 1)   0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 200, 60, 32)  320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 198, 58, 32)  9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 198, 58, 32)  128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 99, 29, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 99, 29, 32)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 99, 29, 64)   18496       dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 97, 27, 64)   36928       conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 97, 27, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 48, 13, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 48, 13, 64)   0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 48, 13, 128)  73856       dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 46, 11, 128)  147584      conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 46, 11, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 23, 5, 128)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 23, 5, 128)   0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 21, 3, 256)   295168      dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 21, 3, 256)   1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 10, 1, 256)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2560)         0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 2560)         0           flatten_1[0][0]
# __________________________________________________________________________________________________
# digit1 (Dense)                  (None, 36)           92196       dropout_4[0][0]
# __________________________________________________________________________________________________
# digit2 (Dense)                  (None, 36)           92196       dropout_4[0][0]
# __________________________________________________________________________________________________
# digit3 (Dense)                  (None, 36)           92196       dropout_4[0][0]
# __________________________________________________________________________________________________
# digit4 (Dense)                  (None, 36)           92196       dropout_4[0][0]
# __________________________________________________________________________________________________
# digit5 (Dense)                  (None, 36)           92196       dropout_4[0][0]
# __________________________________________________________________________________________________
# digit6 (Dense)                  (None, 36)           92196       dropout_4[0][0]
# __________________________________________________________________________________________________
# digit7 (Dense)                  (None, 36)           92196       dropout_4[0][0]
# ==================================================================================================
# Total params: 1,228,892
# Trainable params: 1,227,932
# Non-trainable params: 960
# __________________________________________________________________________________________________

# %%
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True,dpi=60)

# %%
# for storing logs into tensorboard
logdir="logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)

hist = model.fit(X_train, [y_train[0], y_train[1], y_train[2],y_train[3],y_train[4],y_train[5],y_train[6]], batch_size=32, epochs=30,verbose=1, validation_split=0.2,callbacks=[tensorboard_callback])
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 72000 samples, validate on 18000 samples
# Epoch 1/30
# 72000/72000 [==============================] - 329s 5ms/step - loss: 18.3779 - digit1_loss: 2.6233 - digit2_loss: 2.6273 - digit3_loss: 2.6202 - digit4_loss: 2.6324 - digit5_loss: 2.6255 - digit6_loss: 2.6241 - digit7_loss: 2.6251 - digit1_accuracy: 0.1120 - digit2_accuracy: 0.1084 - digit3_accuracy: 0.1103 - digit4_accuracy: 0.1083 - digit5_accuracy: 0.1101 - digit6_accuracy: 0.1086 - digit7_accuracy: 0.1080 - val_loss: 18.2231 - val_digit1_loss: 2.6404 - val_digit2_loss: 2.5754 - val_digit3_loss: 2.5765 - val_digit4_loss: 2.6150 - val_digit5_loss: 2.6358 - val_digit6_loss: 2.6079 - val_digit7_loss: 2.5721 - val_digit1_accuracy: 0.1226 - val_digit2_accuracy: 0.1293 - val_digit3_accuracy: 0.1289 - val_digit4_accuracy: 0.1238 - val_digit5_accuracy: 0.1209 - val_digit6_accuracy: 0.1264 - val_digit7_accuracy: 0.1242
# Epoch 2/30
# 72000/72000 [==============================] - 321s 4ms/step - loss: 16.4661 - digit1_loss: 2.3086 - digit2_loss: 2.3754 - digit3_loss: 2.3693 - digit4_loss: 2.3380 - digit5_loss: 2.3435 - digit6_loss: 2.4071 - digit7_loss: 2.3241 - digit1_accuracy: 0.1833 - digit2_accuracy: 0.1628 - digit3_accuracy: 0.1651 - digit4_accuracy: 0.1728 - digit5_accuracy: 0.1766 - digit6_accuracy: 0.1527 - digit7_accuracy: 0.1778 - val_loss: 15.5929 - val_digit1_loss: 2.1385 - val_digit2_loss: 2.2823 - val_digit3_loss: 2.2229 - val_digit4_loss: 2.1820 - val_digit5_loss: 2.2349 - val_digit6_loss: 2.3231 - val_digit7_loss: 2.2092 - val_digit1_accuracy: 0.2623 - val_digit2_accuracy: 0.2047 - val_digit3_accuracy: 0.2206 - val_digit4_accuracy: 0.2440 - val_digit5_accuracy: 0.2322 - val_digit6_accuracy: 0.1954 - val_digit7_accuracy: 0.2309
# Epoch 3/30
# 72000/72000 [==============================] - 321s 4ms/step - loss: 14.5932 - digit1_loss: 2.0181 - digit2_loss: 2.1168 - digit3_loss: 2.0998 - digit4_loss: 2.0616 - digit5_loss: 2.0917 - digit6_loss: 2.1705 - digit7_loss: 2.0347 - digit1_accuracy: 0.2888 - digit2_accuracy: 0.2493 - digit3_accuracy: 0.2522 - digit4_accuracy: 0.2742 - digit5_accuracy: 0.2660 - digit6_accuracy: 0.2291 - digit7_accuracy: 0.2770 - val_loss: 14.6888 - val_digit1_loss: 2.0010 - val_digit2_loss: 2.0935 - val_digit3_loss: 2.1336 - val_digit4_loss: 2.0677 - val_digit5_loss: 2.1224 - val_digit6_loss: 2.2261 - val_digit7_loss: 2.0449 - val_digit1_accuracy: 0.3465 - val_digit2_accuracy: 0.3011 - val_digit3_accuracy: 0.2728 - val_digit4_accuracy: 0.3142 - val_digit5_accuracy: 0.2819 - val_digit6_accuracy: 0.2465 - val_digit7_accuracy: 0.3149
# Epoch 4/30
# 72000/72000 [==============================] - 320s 4ms/step - loss: 13.4273 - digit1_loss: 1.8254 - digit2_loss: 1.9682 - digit3_loss: 1.9411 - digit4_loss: 1.8881 - digit5_loss: 1.9228 - digit6_loss: 2.0313 - digit7_loss: 1.8504 - digit1_accuracy: 0.3741 - digit2_accuracy: 0.3162 - digit3_accuracy: 0.3284 - digit4_accuracy: 0.3536 - digit5_accuracy: 0.3454 - digit6_accuracy: 0.2913 - digit7_accuracy: 0.3652 - val_loss: 12.2766 - val_digit1_loss: 1.6375 - val_digit2_loss: 1.8234 - val_digit3_loss: 1.7879 - val_digit4_loss: 1.7104 - val_digit5_loss: 1.7588 - val_digit6_loss: 1.8689 - val_digit7_loss: 1.6901 - val_digit1_accuracy: 0.4661 - val_digit2_accuracy: 0.3865 - val_digit3_accuracy: 0.3924 - val_digit4_accuracy: 0.4340 - val_digit5_accuracy: 0.4188 - val_digit6_accuracy: 0.3668 - val_digit7_accuracy: 0.4327
# Epoch 5/30
# 72000/72000 [==============================] - 319s 4ms/step - loss: 12.4250 - digit1_loss: 1.6694 - digit2_loss: 1.8318 - digit3_loss: 1.8071 - digit4_loss: 1.7344 - digit5_loss: 1.7764 - digit6_loss: 1.9128 - digit7_loss: 1.6931 - digit1_accuracy: 0.4420 - digit2_accuracy: 0.3752 - digit3_accuracy: 0.3848 - digit4_accuracy: 0.4201 - digit5_accuracy: 0.4083 - digit6_accuracy: 0.3462 - digit7_accuracy: 0.4351 - val_loss: 11.2432 - val_digit1_loss: 1.4882 - val_digit2_loss: 1.6795 - val_digit3_loss: 1.6244 - val_digit4_loss: 1.5602 - val_digit5_loss: 1.6138 - val_digit6_loss: 1.7515 - val_digit7_loss: 1.5259 - val_digit1_accuracy: 0.5271 - val_digit2_accuracy: 0.4544 - val_digit3_accuracy: 0.4644 - val_digit4_accuracy: 0.5031 - val_digit5_accuracy: 0.4886 - val_digit6_accuracy: 0.4218 - val_digit7_accuracy: 0.5123
# Epoch 6/30
# 72000/72000 [==============================] - 319s 4ms/step - loss: 11.6704 - digit1_loss: 1.5476 - digit2_loss: 1.7304 - digit3_loss: 1.7040 - digit4_loss: 1.6245 - digit5_loss: 1.6659 - digit6_loss: 1.8210 - digit7_loss: 1.5771 - digit1_accuracy: 0.4888 - digit2_accuracy: 0.4212 - digit3_accuracy: 0.4273 - digit4_accuracy: 0.4649 - digit5_accuracy: 0.4519 - digit6_accuracy: 0.3845 - digit7_accuracy: 0.4811 - val_loss: 10.4477 - val_digit1_loss: 1.3656 - val_digit2_loss: 1.5750 - val_digit3_loss: 1.5097 - val_digit4_loss: 1.4398 - val_digit5_loss: 1.5045 - val_digit6_loss: 1.6518 - val_digit7_loss: 1.4018 - val_digit1_accuracy: 0.5778 - val_digit2_accuracy: 0.5001 - val_digit3_accuracy: 0.5174 - val_digit4_accuracy: 0.5486 - val_digit5_accuracy: 0.5251 - val_digit6_accuracy: 0.4642 - val_digit7_accuracy: 0.5654
# Epoch 7/30
# 72000/72000 [==============================] - 320s 4ms/step - loss: 11.0122 - digit1_loss: 1.4459 - digit2_loss: 1.6441 - digit3_loss: 1.6096 - digit4_loss: 1.5210 - digit5_loss: 1.5686 - digit6_loss: 1.7472 - digit7_loss: 1.4759 - digit1_accuracy: 0.5307 - digit2_accuracy: 0.4566 - digit3_accuracy: 0.4659 - digit4_accuracy: 0.5058 - digit5_accuracy: 0.4889 - digit6_accuracy: 0.4152 - digit7_accuracy: 0.5194 - val_loss: 9.7515 - val_digit1_loss: 1.2589 - val_digit2_loss: 1.4777 - val_digit3_loss: 1.4259 - val_digit4_loss: 1.3402 - val_digit5_loss: 1.3945 - val_digit6_loss: 1.5617 - val_digit7_loss: 1.2929 - val_digit1_accuracy: 0.6194 - val_digit2_accuracy: 0.5463 - val_digit3_accuracy: 0.5589 - val_digit4_accuracy: 0.5938 - val_digit5_accuracy: 0.5811 - val_digit6_accuracy: 0.5036 - val_digit7_accuracy: 0.6119
# Epoch 8/30
# 72000/72000 [==============================] - 320s 4ms/step - loss: 10.4613 - digit1_loss: 1.3576 - digit2_loss: 1.5711 - digit3_loss: 1.5364 - digit4_loss: 1.4376 - digit5_loss: 1.4931 - digit6_loss: 1.6766 - digit7_loss: 1.3889 - digit1_accuracy: 0.5630 - digit2_accuracy: 0.4864 - digit3_accuracy: 0.4948 - digit4_accuracy: 0.5374 - digit5_accuracy: 0.5200 - digit6_accuracy: 0.4427 - digit7_accuracy: 0.5523 - val_loss: 9.2296 - val_digit1_loss: 1.1654 - val_digit2_loss: 1.4136 - val_digit3_loss: 1.3489 - val_digit4_loss: 1.2594 - val_digit5_loss: 1.3223 - val_digit6_loss: 1.5008 - val_digit7_loss: 1.2198 - val_digit1_accuracy: 0.6602 - val_digit2_accuracy: 0.5712 - val_digit3_accuracy: 0.5912 - val_digit4_accuracy: 0.6227 - val_digit5_accuracy: 0.6073 - val_digit6_accuracy: 0.5285 - val_digit7_accuracy: 0.6347
# Epoch 9/30
# 72000/72000 [==============================] - 321s 4ms/step - loss: 9.9840 - digit1_loss: 1.2824 - digit2_loss: 1.5028 - digit3_loss: 1.4691 - digit4_loss: 1.3590 - digit5_loss: 1.4222 - digit6_loss: 1.6215 - digit7_loss: 1.3269 - digit1_accuracy: 0.5924 - digit2_accuracy: 0.5119 - digit3_accuracy: 0.5213 - digit4_accuracy: 0.5658 - digit5_accuracy: 0.5457 - digit6_accuracy: 0.4637 - digit7_accuracy: 0.5730 - val_loss: 8.7139 - val_digit1_loss: 1.0928 - val_digit2_loss: 1.3457 - val_digit3_loss: 1.2784 - val_digit4_loss: 1.1728 - val_digit5_loss: 1.2438 - val_digit6_loss: 1.4356 - val_digit7_loss: 1.1457 - val_digit1_accuracy: 0.6900 - val_digit2_accuracy: 0.6001 - val_digit3_accuracy: 0.6182 - val_digit4_accuracy: 0.6594 - val_digit5_accuracy: 0.6444 - val_digit6_accuracy: 0.5634 - val_digit7_accuracy: 0.6680
# Epoch 10/30
# 72000/72000 [==============================] - 320s 4ms/step - loss: 9.5623 - digit1_loss: 1.2163 - digit2_loss: 1.4492 - digit3_loss: 1.4076 - digit4_loss: 1.2957 - digit5_loss: 1.3648 - digit6_loss: 1.5706 - digit7_loss: 1.2580 - digit1_accuracy: 0.6175 - digit2_accuracy: 0.5325 - digit3_accuracy: 0.5439 - digit4_accuracy: 0.5900 - digit5_accuracy: 0.5661 - digit6_accuracy: 0.4808 - digit7_accuracy: 0.5999 - val_loss: 8.2911 - val_digit1_loss: 1.0381 - val_digit2_loss: 1.2833 - val_digit3_loss: 1.2063 - val_digit4_loss: 1.1052 - val_digit5_loss: 1.1947 - val_digit6_loss: 1.3901 - val_digit7_loss: 1.0744 - val_digit1_accuracy: 0.7094 - val_digit2_accuracy: 0.6220 - val_digit3_accuracy: 0.6429 - val_digit4_accuracy: 0.6851 - val_digit5_accuracy: 0.6547 - val_digit6_accuracy: 0.5798 - val_digit7_accuracy: 0.6943
# Epoch 11/30
# 72000/72000 [==============================] - 318s 4ms/step - loss: 9.1963 - digit1_loss: 1.1627 - digit2_loss: 1.3969 - digit3_loss: 1.3543 - digit4_loss: 1.2394 - digit5_loss: 1.3093 - digit6_loss: 1.5237 - digit7_loss: 1.2100 - digit1_accuracy: 0.6354 - digit2_accuracy: 0.5499 - digit3_accuracy: 0.5623 - digit4_accuracy: 0.6076 - digit5_accuracy: 0.5888 - digit6_accuracy: 0.5009 - digit7_accuracy: 0.6184 - val_loss: 7.9596 - val_digit1_loss: 0.9748 - val_digit2_loss: 1.2369 - val_digit3_loss: 1.1736 - val_digit4_loss: 1.0573 - val_digit5_loss: 1.1435 - val_digit6_loss: 1.3466 - val_digit7_loss: 1.0275 - val_digit1_accuracy: 0.7310 - val_digit2_accuracy: 0.6377 - val_digit3_accuracy: 0.6543 - val_digit4_accuracy: 0.6997 - val_digit5_accuracy: 0.6767 - val_digit6_accuracy: 0.5946 - val_digit7_accuracy: 0.7121
# Epoch 12/30
# 72000/72000 [==============================] - 320s 4ms/step - loss: 8.8859 - digit1_loss: 1.1138 - digit2_loss: 1.3511 - digit3_loss: 1.3046 - digit4_loss: 1.1992 - digit5_loss: 1.2647 - digit6_loss: 1.4834 - digit7_loss: 1.1690 - digit1_accuracy: 0.6524 - digit2_accuracy: 0.5668 - digit3_accuracy: 0.5802 - digit4_accuracy: 0.6230 - digit5_accuracy: 0.6028 - digit6_accuracy: 0.5162 - digit7_accuracy: 0.6327 - val_loss: 7.6330 - val_digit1_loss: 0.9362 - val_digit2_loss: 1.1817 - val_digit3_loss: 1.1196 - val_digit4_loss: 1.0145 - val_digit5_loss: 1.0928 - val_digit6_loss: 1.2888 - val_digit7_loss: 1.0007 - val_digit1_accuracy: 0.7478 - val_digit2_accuracy: 0.6631 - val_digit3_accuracy: 0.6741 - val_digit4_accuracy: 0.7152 - val_digit5_accuracy: 0.6944 - val_digit6_accuracy: 0.6201 - val_digit7_accuracy: 0.7192
# Epoch 13/30
# 72000/72000 [==============================] - 319s 4ms/step - loss: 8.6265 - digit1_loss: 1.0837 - digit2_loss: 1.3115 - digit3_loss: 1.2627 - digit4_loss: 1.1596 - digit5_loss: 1.2266 - digit6_loss: 1.4479 - digit7_loss: 1.1345 - digit1_accuracy: 0.6612 - digit2_accuracy: 0.5775 - digit3_accuracy: 0.5946 - digit4_accuracy: 0.6371 - digit5_accuracy: 0.6152 - digit6_accuracy: 0.5271 - digit7_accuracy: 0.6433 - val_loss: 7.4283 - val_digit1_loss: 0.9124 - val_digit2_loss: 1.1624 - val_digit3_loss: 1.0787 - val_digit4_loss: 0.9901 - val_digit5_loss: 1.0658 - val_digit6_loss: 1.2567 - val_digit7_loss: 0.9634 - val_digit1_accuracy: 0.7521 - val_digit2_accuracy: 0.6659 - val_digit3_accuracy: 0.6872 - val_digit4_accuracy: 0.7227 - val_digit5_accuracy: 0.6979 - val_digit6_accuracy: 0.6266 - val_digit7_accuracy: 0.7321
# Epoch 14/30
# 72000/72000 [==============================] - 321s 4ms/step - loss: 8.4124 - digit1_loss: 1.0481 - digit2_loss: 1.2825 - digit3_loss: 1.2349 - digit4_loss: 1.1288 - digit5_loss: 1.2003 - digit6_loss: 1.4173 - digit7_loss: 1.1005 - digit1_accuracy: 0.6734 - digit2_accuracy: 0.5928 - digit3_accuracy: 0.6074 - digit4_accuracy: 0.6464 - digit5_accuracy: 0.6253 - digit6_accuracy: 0.5385 - digit7_accuracy: 0.6548 - val_loss: 7.1975 - val_digit1_loss: 0.8850 - val_digit2_loss: 1.1257 - val_digit3_loss: 1.0388 - val_digit4_loss: 0.9590 - val_digit5_loss: 1.0327 - val_digit6_loss: 1.2173 - val_digit7_loss: 0.9400 - val_digit1_accuracy: 0.7630 - val_digit2_accuracy: 0.6838 - val_digit3_accuracy: 0.7053 - val_digit4_accuracy: 0.7366 - val_digit5_accuracy: 0.7153 - val_digit6_accuracy: 0.6471 - val_digit7_accuracy: 0.7377
# Epoch 15/30
# 72000/72000 [==============================] - 318s 4ms/step - loss: 8.2099 - digit1_loss: 1.0177 - digit2_loss: 1.2562 - digit3_loss: 1.2063 - digit4_loss: 1.0988 - digit5_loss: 1.1692 - digit6_loss: 1.3897 - digit7_loss: 1.0720 - digit1_accuracy: 0.6835 - digit2_accuracy: 0.5978 - digit3_accuracy: 0.6150 - digit4_accuracy: 0.6546 - digit5_accuracy: 0.6344 - digit6_accuracy: 0.5497 - digit7_accuracy: 0.6654 - val_loss: 7.1233 - val_digit1_loss: 0.8771 - val_digit2_loss: 1.1066 - val_digit3_loss: 1.0303 - val_digit4_loss: 0.9488 - val_digit5_loss: 1.0225 - val_digit6_loss: 1.2107 - val_digit7_loss: 0.9283 - val_digit1_accuracy: 0.7676 - val_digit2_accuracy: 0.6947 - val_digit3_accuracy: 0.7098 - val_digit4_accuracy: 0.7394 - val_digit5_accuracy: 0.7205 - val_digit6_accuracy: 0.6496 - val_digit7_accuracy: 0.7489
# Epoch 16/30
# 72000/72000 [==============================] - 318s 4ms/step - loss: 8.0326 - digit1_loss: 0.9904 - digit2_loss: 1.2378 - digit3_loss: 1.1755 - digit4_loss: 1.0741 - digit5_loss: 1.1452 - digit6_loss: 1.3626 - digit7_loss: 1.0471 - digit1_accuracy: 0.6928 - digit2_accuracy: 0.6068 - digit3_accuracy: 0.6255 - digit4_accuracy: 0.6672 - digit5_accuracy: 0.6437 - digit6_accuracy: 0.5588 - digit7_accuracy: 0.6724 - val_loss: 6.8903 - val_digit1_loss: 0.8431 - val_digit2_loss: 1.0699 - val_digit3_loss: 0.9985 - val_digit4_loss: 0.9151 - val_digit5_loss: 0.9926 - val_digit6_loss: 1.1764 - val_digit7_loss: 0.8958 - val_digit1_accuracy: 0.7778 - val_digit2_accuracy: 0.7026 - val_digit3_accuracy: 0.7194 - val_digit4_accuracy: 0.7523 - val_digit5_accuracy: 0.7287 - val_digit6_accuracy: 0.6630 - val_digit7_accuracy: 0.7570
# Epoch 17/30
# 72000/72000 [==============================] - 320s 4ms/step - loss: 7.8627 - digit1_loss: 0.9682 - digit2_loss: 1.2079 - digit3_loss: 1.1488 - digit4_loss: 1.0520 - digit5_loss: 1.1234 - digit6_loss: 1.3386 - digit7_loss: 1.0239 - digit1_accuracy: 0.6998 - digit2_accuracy: 0.6141 - digit3_accuracy: 0.6337 - digit4_accuracy: 0.6729 - digit5_accuracy: 0.6489 - digit6_accuracy: 0.5657 - digit7_accuracy: 0.6819 - val_loss: 6.6979 - val_digit1_loss: 0.8202 - val_digit2_loss: 1.0413 - val_digit3_loss: 0.9721 - val_digit4_loss: 0.8906 - val_digit5_loss: 0.9585 - val_digit6_loss: 1.1410 - val_digit7_loss: 0.8752 - val_digit1_accuracy: 0.7856 - val_digit2_accuracy: 0.7131 - val_digit3_accuracy: 0.7328 - val_digit4_accuracy: 0.7596 - val_digit5_accuracy: 0.7410 - val_digit6_accuracy: 0.6766 - val_digit7_accuracy: 0.7680
# Epoch 18/30
# 72000/72000 [==============================] - 319s 4ms/step - loss: 7.7110 - digit1_loss: 0.9488 - digit2_loss: 1.1887 - digit3_loss: 1.1284 - digit4_loss: 1.0321 - digit5_loss: 1.0987 - digit6_loss: 1.3132 - digit7_loss: 1.0012 - digit1_accuracy: 0.7057 - digit2_accuracy: 0.6245 - digit3_accuracy: 0.6399 - digit4_accuracy: 0.6794 - digit5_accuracy: 0.6578 - digit6_accuracy: 0.5741 - digit7_accuracy: 0.6891 - val_loss: 6.6315 - val_digit1_loss: 0.8067 - val_digit2_loss: 1.0288 - val_digit3_loss: 0.9587 - val_digit4_loss: 0.8915 - val_digit5_loss: 0.9497 - val_digit6_loss: 1.1253 - val_digit7_loss: 0.8719 - val_digit1_accuracy: 0.7910 - val_digit2_accuracy: 0.7202 - val_digit3_accuracy: 0.7347 - val_digit4_accuracy: 0.7617 - val_digit5_accuracy: 0.7433 - val_digit6_accuracy: 0.6830 - val_digit7_accuracy: 0.7659
# Epoch 19/30
# 72000/72000 [==============================] - 319s 4ms/step - loss: 7.6002 - digit1_loss: 0.9295 - digit2_loss: 1.1704 - digit3_loss: 1.1136 - digit4_loss: 1.0157 - digit5_loss: 1.0816 - digit6_loss: 1.3004 - digit7_loss: 0.9891 - digit1_accuracy: 0.7131 - digit2_accuracy: 0.6296 - digit3_accuracy: 0.6460 - digit4_accuracy: 0.6861 - digit5_accuracy: 0.6634 - digit6_accuracy: 0.5814 - digit7_accuracy: 0.6919 - val_loss: 6.4625 - val_digit1_loss: 0.7902 - val_digit2_loss: 1.0111 - val_digit3_loss: 0.9310 - val_digit4_loss: 0.8588 - val_digit5_loss: 0.9290 - val_digit6_loss: 1.1068 - val_digit7_loss: 0.8367 - val_digit1_accuracy: 0.7988 - val_digit2_accuracy: 0.7259 - val_digit3_accuracy: 0.7464 - val_digit4_accuracy: 0.7731 - val_digit5_accuracy: 0.7515 - val_digit6_accuracy: 0.6912 - val_digit7_accuracy: 0.7768
# Epoch 20/30
# 72000/72000 [==============================] - 319s 4ms/step - loss: 7.4656 - digit1_loss: 0.9131 - digit2_loss: 1.1537 - digit3_loss: 1.0874 - digit4_loss: 0.9932 - digit5_loss: 1.0659 - digit6_loss: 1.2774 - digit7_loss: 0.9749 - digit1_accuracy: 0.7163 - digit2_accuracy: 0.6339 - digit3_accuracy: 0.6550 - digit4_accuracy: 0.6919 - digit5_accuracy: 0.6702 - digit6_accuracy: 0.5869 - digit7_accuracy: 0.6970 - val_loss: 6.3745 - val_digit1_loss: 0.7777 - val_digit2_loss: 1.0022 - val_digit3_loss: 0.9095 - val_digit4_loss: 0.8500 - val_digit5_loss: 0.9180 - val_digit6_loss: 1.0864 - val_digit7_loss: 0.8318 - val_digit1_accuracy: 0.7981 - val_digit2_accuracy: 0.7272 - val_digit3_accuracy: 0.7522 - val_digit4_accuracy: 0.7727 - val_digit5_accuracy: 0.7553 - val_digit6_accuracy: 0.6937 - val_digit7_accuracy: 0.7752
# Epoch 21/30
# 72000/72000 [==============================] - 323s 4ms/step - loss: 7.3523 - digit1_loss: 0.9045 - digit2_loss: 1.1389 - digit3_loss: 1.0727 - digit4_loss: 0.9785 - digit5_loss: 1.0463 - digit6_loss: 1.2604 - digit7_loss: 0.9511 - digit1_accuracy: 0.7201 - digit2_accuracy: 0.6376 - digit3_accuracy: 0.6607 - digit4_accuracy: 0.6985 - digit5_accuracy: 0.6756 - digit6_accuracy: 0.5924 - digit7_accuracy: 0.7033 - val_loss: 6.3026 - val_digit1_loss: 0.7692 - val_digit2_loss: 0.9922 - val_digit3_loss: 0.9146 - val_digit4_loss: 0.8396 - val_digit5_loss: 0.8991 - val_digit6_loss: 1.0721 - val_digit7_loss: 0.8168 - val_digit1_accuracy: 0.8009 - val_digit2_accuracy: 0.7345 - val_digit3_accuracy: 0.7457 - val_digit4_accuracy: 0.7746 - val_digit5_accuracy: 0.7586 - val_digit6_accuracy: 0.7008 - val_digit7_accuracy: 0.7807
# Epoch 22/30
# 72000/72000 [==============================] - 323s 4ms/step - loss: 7.2716 - digit1_loss: 0.8829 - digit2_loss: 1.1288 - digit3_loss: 1.0663 - digit4_loss: 0.9722 - digit5_loss: 1.0397 - digit6_loss: 1.2461 - digit7_loss: 0.9357 - digit1_accuracy: 0.7275 - digit2_accuracy: 0.6442 - digit3_accuracy: 0.6608 - digit4_accuracy: 0.6992 - digit5_accuracy: 0.6765 - digit6_accuracy: 0.5985 - digit7_accuracy: 0.7102 - val_loss: 6.2438 - val_digit1_loss: 0.7558 - val_digit2_loss: 0.9762 - val_digit3_loss: 0.9086 - val_digit4_loss: 0.8273 - val_digit5_loss: 0.8957 - val_digit6_loss: 1.0655 - val_digit7_loss: 0.8158 - val_digit1_accuracy: 0.8064 - val_digit2_accuracy: 0.7399 - val_digit3_accuracy: 0.7516 - val_digit4_accuracy: 0.7803 - val_digit5_accuracy: 0.7602 - val_digit6_accuracy: 0.7007 - val_digit7_accuracy: 0.7848
# Epoch 23/30
# 72000/72000 [==============================] - 321s 4ms/step - loss: 7.1771 - digit1_loss: 0.8727 - digit2_loss: 1.1112 - digit3_loss: 1.0486 - digit4_loss: 0.9592 - digit5_loss: 1.0279 - digit6_loss: 1.2295 - digit7_loss: 0.9279 - digit1_accuracy: 0.7310 - digit2_accuracy: 0.6498 - digit3_accuracy: 0.6671 - digit4_accuracy: 0.7027 - digit5_accuracy: 0.6821 - digit6_accuracy: 0.6037 - digit7_accuracy: 0.7097 - val_loss: 6.1686 - val_digit1_loss: 0.7449 - val_digit2_loss: 0.9678 - val_digit3_loss: 0.8840 - val_digit4_loss: 0.8284 - val_digit5_loss: 0.8889 - val_digit6_loss: 1.0501 - val_digit7_loss: 0.8054 - val_digit1_accuracy: 0.8101 - val_digit2_accuracy: 0.7418 - val_digit3_accuracy: 0.7584 - val_digit4_accuracy: 0.7838 - val_digit5_accuracy: 0.7658 - val_digit6_accuracy: 0.7132 - val_digit7_accuracy: 0.7913
# Epoch 24/30
# 72000/72000 [==============================] - 320s 4ms/step - loss: 7.0872 - digit1_loss: 0.8589 - digit2_loss: 1.0993 - digit3_loss: 1.0382 - digit4_loss: 0.9422 - digit5_loss: 1.0138 - digit6_loss: 1.2172 - digit7_loss: 0.9176 - digit1_accuracy: 0.7332 - digit2_accuracy: 0.6537 - digit3_accuracy: 0.6709 - digit4_accuracy: 0.7081 - digit5_accuracy: 0.6851 - digit6_accuracy: 0.6082 - digit7_accuracy: 0.7133 - val_loss: 6.1013 - val_digit1_loss: 0.7429 - val_digit2_loss: 0.9585 - val_digit3_loss: 0.8776 - val_digit4_loss: 0.8078 - val_digit5_loss: 0.8781 - val_digit6_loss: 1.0345 - val_digit7_loss: 0.8029 - val_digit1_accuracy: 0.8137 - val_digit2_accuracy: 0.7457 - val_digit3_accuracy: 0.7586 - val_digit4_accuracy: 0.7883 - val_digit5_accuracy: 0.7695 - val_digit6_accuracy: 0.7144 - val_digit7_accuracy: 0.7894
# Epoch 25/30
# 72000/72000 [==============================] - 319s 4ms/step - loss: 7.0176 - digit1_loss: 0.8511 - digit2_loss: 1.0902 - digit3_loss: 1.0272 - digit4_loss: 0.9305 - digit5_loss: 1.0041 - digit6_loss: 1.2103 - digit7_loss: 0.9043 - digit1_accuracy: 0.7362 - digit2_accuracy: 0.6558 - digit3_accuracy: 0.6728 - digit4_accuracy: 0.7133 - digit5_accuracy: 0.6884 - digit6_accuracy: 0.6092 - digit7_accuracy: 0.7172 - val_loss: 5.9864 - val_digit1_loss: 0.7264 - val_digit2_loss: 0.9389 - val_digit3_loss: 0.8582 - val_digit4_loss: 0.7990 - val_digit5_loss: 0.8616 - val_digit6_loss: 1.0231 - val_digit7_loss: 0.7801 - val_digit1_accuracy: 0.8158 - val_digit2_accuracy: 0.7502 - val_digit3_accuracy: 0.7678 - val_digit4_accuracy: 0.7909 - val_digit5_accuracy: 0.7726 - val_digit6_accuracy: 0.7165 - val_digit7_accuracy: 0.7965
# Epoch 26/30
# 72000/72000 [==============================] - 322s 4ms/step - loss: 6.9196 - digit1_loss: 0.8405 - digit2_loss: 1.0759 - digit3_loss: 1.0083 - digit4_loss: 0.9233 - digit5_loss: 0.9860 - digit6_loss: 1.1926 - digit7_loss: 0.8930 - digit1_accuracy: 0.7401 - digit2_accuracy: 0.6581 - digit3_accuracy: 0.6816 - digit4_accuracy: 0.7140 - digit5_accuracy: 0.6952 - digit6_accuracy: 0.6160 - digit7_accuracy: 0.7235 - val_loss: 5.9493 - val_digit1_loss: 0.7188 - val_digit2_loss: 0.9329 - val_digit3_loss: 0.8597 - val_digit4_loss: 0.7904 - val_digit5_loss: 0.8631 - val_digit6_loss: 1.0130 - val_digit7_loss: 0.7725 - val_digit1_accuracy: 0.8204 - val_digit2_accuracy: 0.7518 - val_digit3_accuracy: 0.7653 - val_digit4_accuracy: 0.7929 - val_digit5_accuracy: 0.7728 - val_digit6_accuracy: 0.7225 - val_digit7_accuracy: 0.7976
# Epoch 27/30
# 72000/72000 [==============================] - 319s 4ms/step - loss: 6.8932 - digit1_loss: 0.8298 - digit2_loss: 1.0751 - digit3_loss: 1.0113 - digit4_loss: 0.9160 - digit5_loss: 0.9850 - digit6_loss: 1.1866 - digit7_loss: 0.8894 - digit1_accuracy: 0.7423 - digit2_accuracy: 0.6584 - digit3_accuracy: 0.6826 - digit4_accuracy: 0.7155 - digit5_accuracy: 0.6937 - digit6_accuracy: 0.6172 - digit7_accuracy: 0.7236 - val_loss: 5.9712 - val_digit1_loss: 0.7283 - val_digit2_loss: 0.9327 - val_digit3_loss: 0.8544 - val_digit4_loss: 0.7959 - val_digit5_loss: 0.8570 - val_digit6_loss: 1.0174 - val_digit7_loss: 0.7866 - val_digit1_accuracy: 0.8177 - val_digit2_accuracy: 0.7565 - val_digit3_accuracy: 0.7714 - val_digit4_accuracy: 0.7920 - val_digit5_accuracy: 0.7746 - val_digit6_accuracy: 0.7217 - val_digit7_accuracy: 0.7933
# Epoch 28/30
# 72000/72000 [==============================] - 321s 4ms/step - loss: 6.8050 - digit1_loss: 0.8191 - digit2_loss: 1.0598 - digit3_loss: 0.9960 - digit4_loss: 0.9083 - digit5_loss: 0.9708 - digit6_loss: 1.1810 - digit7_loss: 0.8701 - digit1_accuracy: 0.7453 - digit2_accuracy: 0.6658 - digit3_accuracy: 0.6856 - digit4_accuracy: 0.7186 - digit5_accuracy: 0.6999 - digit6_accuracy: 0.6209 - digit7_accuracy: 0.7289 - val_loss: 5.8723 - val_digit1_loss: 0.7081 - val_digit2_loss: 0.9242 - val_digit3_loss: 0.8457 - val_digit4_loss: 0.7890 - val_digit5_loss: 0.8487 - val_digit6_loss: 0.9922 - val_digit7_loss: 0.7650 - val_digit1_accuracy: 0.8235 - val_digit2_accuracy: 0.7573 - val_digit3_accuracy: 0.7736 - val_digit4_accuracy: 0.7938 - val_digit5_accuracy: 0.7777 - val_digit6_accuracy: 0.7328 - val_digit7_accuracy: 0.8019
# Epoch 29/30
# 72000/72000 [==============================] - 320s 4ms/step - loss: 6.7532 - digit1_loss: 0.8169 - digit2_loss: 1.0464 - digit3_loss: 0.9908 - digit4_loss: 0.8961 - digit5_loss: 0.9687 - digit6_loss: 1.1708 - digit7_loss: 0.8635 - digit1_accuracy: 0.7475 - digit2_accuracy: 0.6681 - digit3_accuracy: 0.6867 - digit4_accuracy: 0.7227 - digit5_accuracy: 0.7000 - digit6_accuracy: 0.6232 - digit7_accuracy: 0.7314 - val_loss: 5.8020 - val_digit1_loss: 0.6988 - val_digit2_loss: 0.9113 - val_digit3_loss: 0.8361 - val_digit4_loss: 0.7735 - val_digit5_loss: 0.8371 - val_digit6_loss: 0.9858 - val_digit7_loss: 0.7605 - val_digit1_accuracy: 0.8268 - val_digit2_accuracy: 0.7616 - val_digit3_accuracy: 0.7798 - val_digit4_accuracy: 0.7978 - val_digit5_accuracy: 0.7782 - val_digit6_accuracy: 0.7317 - val_digit7_accuracy: 0.8012
# Epoch 30/30
# 72000/72000 [==============================] - 320s 4ms/step - loss: 6.6877 - digit1_loss: 0.8101 - digit2_loss: 1.0433 - digit3_loss: 0.9729 - digit4_loss: 0.8902 - digit5_loss: 0.9545 - digit6_loss: 1.1549 - digit7_loss: 0.8619 - digit1_accuracy: 0.7483 - digit2_accuracy: 0.6691 - digit3_accuracy: 0.6925 - digit4_accuracy: 0.7236 - digit5_accuracy: 0.7046 - digit6_accuracy: 0.6298 - digit7_accuracy: 0.7292 - val_loss: 5.8404 - val_digit1_loss: 0.7019 - val_digit2_loss: 0.9206 - val_digit3_loss: 0.8426 - val_digit4_loss: 0.7758 - val_digit5_loss: 0.8538 - val_digit6_loss: 0.9874 - val_digit7_loss: 0.7591 - val_digit1_accuracy: 0.8268 - val_digit2_accuracy: 0.7572 - val_digit3_accuracy: 0.7765 - val_digit4_accuracy: 0.7998 - val_digit5_accuracy: 0.7732 - val_digit6_accuracy: 0.7374 - val_digit7_accuracy: 0.8038

# %%
plt.figure(figsize=(12,7))
legend_acc = []
for item in hist.history.keys():
  if item.split('_')[-1:] == ['acc']:
    #print("Accuracy = ",item)
    legend_acc.append(item)
    plt.plot(hist.history[item])
plt.ylabel('Accuracy ->')
plt.xlabel('Epoch ->')
plt.legend(legend_acc, loc='upper left')
plt.show()

plt.figure(figsize=(12,7))
legend_acc = []
for item in hist.history.keys():
  if item.split('_')[-1:] == ['loss']:
    #print("Accuracy = ",item)
    legend_acc.append(item)
    plt.plot(hist.history[item])
plt.ylabel('Loss ->')
plt.xlabel('Epoch ->')
plt.legend(legend_acc, loc='upper right')
plt.show()

# %%
# Define function to predict captcha
def predict(filepath):
    img = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)
    ret,thresh = cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)
    # firstly perform erosion
    erosion = cv2.erode(thresh,kernel,iterations = 1)
    # perform dialation
    dialate = cv2.dilate(erosion,kernel,iterations = 1)
    img = dialate.copy()
    if img is not None:
        img = img / 255.0
    else:
        print("Not detected");
    #res = np.array(model.predict(img[np.newaxis, :, :, np.newaxis]))
    new_im = img.reshape((img.shape[1],img.shape[0]))
    res = np.array(model.predict(new_im[np.newaxis,:,:,np.newaxis]))
    #print(res)
    ans = np.reshape(res, (7, 36))
    l_ind = []
    probs = []
    for a in ans:
        l_ind.append(np.argmax(a))
        #probs.append(np.max(a))

    capt = ''
    for l in l_ind:
        capt += symbols[l]
    return capt#, sum(probs) / 5

# %%
total_img = 36
num_pr = 6 # number per row

counter = 1
plt.figure(figsize=(30,15))
plt.axis('off')
for item in png_files[:total_img]:
  image = cv2.imread(item, cv2.IMREAD_UNCHANGED)
  pred = predict(item)
  #print(pred)
  image_bckup = image.copy()
  plt.subplot(num_pr, num_pr, counter)
  #print("item => ",item)
  #print("item => ",str(item.split('_')[1]).split('/')[1])
  if str(item.split('_')[1]).split('/')[1] == str(pred):
    plt.title("Prediction = {}".format(pred),fontsize=20).set_color('green')
  else:
    plt.title("Prediction = {}".format(pred),fontsize=20).set_color('red')
  plt.axis('off')
  plt.imshow(image_bckup, cmap=plt.get_cmap('gray'))
  counter += 1
  #break
plt.show()

# %%
score= model.evaluate(X_test,[y_test[0], y_test[1], y_test[2],y_test[3],y_test[4],y_test[5],y_test[6]])
print('Test Loss and accuracy:', score)
# Out:
# 10000/10000 [==============================] - 15s 2ms/step
# Test Loss and accuracy: [5.83897334060669, 0.7040802836418152, 0.898483157157898, 0.8154170513153076, 0.7738478183746338, 0.8573757410049438, 1.0060827732086182, 0.7827491760253906, 0.8238999843597412, 0.7620000243186951, 0.788100004196167, 0.7968000173568726, 0.7756999731063843, 0.7315999865531921, 0.7998999953269958]
